# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# import csv's

median_income = pd.read_csv("./Raw Data Files/Median Income.csv", encoding='latin1')
median_home_value_acs = pd.read_csv("./Raw Data Files/Median Home Value - ACS.csv", encoding='latin1')
zillow_home_value = pd.read_csv("./Raw Data Files/Zillow Home Value.csv", encoding='latin1')
zillow_bottom_tier = pd.read_csv("./Raw Data Files/Zillow Bottom Tier Home Value.csv", encoding='latin1')
zillow_top_tier = pd.read_csv("./Raw Data Files/Zillow Top Tier Home Value.csv", encoding='latin1')

# %%
# refine housing and income data by selecting relevant columns and renaming columns

median_income = median_income[["Geography","County","state","Mean income (dollars); Estimate; All households"]]
median_income = median_income.rename(columns={"state":"State","Mean income (dollars); Estimate; All households":"Median Income"})

median_home_value_acs = median_home_value_acs[["Geography","Estimate; Median value (dollars)"]]
median_home_value_acs = median_home_value_acs.rename(columns={"Estimate; Median value (dollars)":"ACS Home Value"})

zillow_home_value = zillow_home_value[["geography","Zhvi"]]
zillow_home_value = zillow_home_value.rename(columns={"geography":"Geography","Zhvi":"Zillow Home Value"})

zillow_bottom_tier = zillow_bottom_tier[["Geography","2018-12"]]
zillow_bottom_tier = zillow_bottom_tier.rename(columns={"2018-12":"Zillow Bottom Tier Home Value"})

zillow_top_tier = zillow_top_tier[["Geography","2018-12"]]
zillow_top_tier = zillow_top_tier.rename(columns={"2018-12":"Zillow Top Tier Home Value"})

# create a csv for the county and state data

output_data = median_income[["Geography","County","State"]]

output_data.to_csv("./Interim Data Files/State and County Info.csv", index=False, header=True)

# %%
# merge data into one table
data_table = pd.merge(median_income,median_home_value_acs,how='left',on='Geography')
data_table = pd.merge(data_table,zillow_home_value,how='left', on='Geography')
data_table = pd.merge(data_table,zillow_bottom_tier,how='left', on='Geography')
data_table = pd.merge(data_table,zillow_top_tier,how='left', on='Geography')

# %%
data_table.head(100)
# Out:
#                                     Geography  \
# 0                     Autauga County, Alabama
# 1                     Baldwin County, Alabama
# 2                     Barbour County, Alabama
# 3                        Bibb County, Alabama
# 4                      Blount County, Alabama
# 5                     Bullock County, Alabama
# 6                      Butler County, Alabama
# 7                     Calhoun County, Alabama
# 8                    Chambers County, Alabama
# 9                    Cherokee County, Alabama
# 10                    Chilton County, Alabama
# 11                    Choctaw County, Alabama
# 12                     Clarke County, Alabama
# 13                       Clay County, Alabama
# 14                   Cleburne County, Alabama
# 15                     Coffee County, Alabama
# 16                    Colbert County, Alabama
# 17                    Conecuh County, Alabama
# 18                      Coosa County, Alabama
# 19                  Covington County, Alabama
# 20                   Crenshaw County, Alabama
# 21                    Cullman County, Alabama
# 22                       Dale County, Alabama
# 23                     Dallas County, Alabama
# 24                     DeKalb County, Alabama
# 25                     Elmore County, Alabama
# 26                   Escambia County, Alabama
# 27                     Etowah County, Alabama
# 28                    Fayette County, Alabama
# 29                   Franklin County, Alabama
# ..                                        ...
# 70                 Bethel Census Area, Alaska
# 71                Bristol Bay Borough, Alaska
# 72                     Denali Borough, Alaska
# 73             Dillingham Census Area, Alaska
# 74       Fairbanks North Star Borough, Alaska
# 75                     Haines Borough, Alaska
# 76          Hoonah-Angoon Census Area, Alaska
# 77            Juneau City and Borough, Alaska
# 78            Kenai Peninsula Borough, Alaska
# 79          Ketchikan Gateway Borough, Alaska
# 80              Kodiak Island Borough, Alaska
# 81               Kusilvak Census Area, Alaska
# 82         Lake and Peninsula Borough, Alaska
# 83          Matanuska-Susitna Borough, Alaska
# 84                   Nome Census Area, Alaska
# 85                North Slope Borough, Alaska
# 86           Northwest Arctic Borough, Alaska
# 87                 Petersburg Borough, Alaska
# 88  Prince of Wales-Hyder Census Area, Alaska
# 89             Sitka City and Borough, Alaska
# 90               Skagway Municipality, Alaska
# 91    Southeast Fairbanks Census Area, Alaska
# 92         Valdez-Cordova Census Area, Alaska
# 93          Wrangell City and Borough, Alaska
# 94           Yakutat City and Borough, Alaska
# 95          Yukon-Koyukuk Census Area, Alaska
# 96                     Apache County, Arizona
# 97                    Cochise County, Arizona
# 98                   Coconino County, Arizona
# 99                       Gila County, Arizona
#
#                                County    State  Median Income ACS Home Value  \
# 0                      Autauga County  Alabama          72110         143000
# 1                      Baldwin County  Alabama          73061         182000
# 2                      Barbour County  Alabama          45445          89300
# 3                         Bibb County  Alabama          61099         105500
# 4                       Blount County  Alabama          58974         122200
# 5                      Bullock County  Alabama          42317          66800
# 6                       Butler County  Alabama          47812          88800
# 7                      Calhoun County  Alabama          58788         110100
# 8                     Chambers County  Alabama          51434          86400
# 9                     Cherokee County  Alabama          54671         116300
# 10                     Chilton County  Alabama          59036          98600
# 11                     Choctaw County  Alabama          48466          69000
# 12                      Clarke County  Alabama          50851          93500
# 13                        Clay County  Alabama          51364          89300
# 14                    Cleburne County  Alabama          51607         111800
# 15                      Coffee County  Alabama          65863         147800
# 16                     Colbert County  Alabama          56372         108500
# 17                     Conecuh County  Alabama          39554          76100
# 18                       Coosa County  Alabama          48059          87300
# 19                   Covington County  Alabama          53372          96200
# 20                    Crenshaw County  Alabama          52395          76800
# 21                     Cullman County  Alabama          55135         121900
# 22                        Dale County  Alabama          57087         108000
# 23                      Dallas County  Alabama          44023          80800
# 24                      DeKalb County  Alabama          52462         102900
# 25                      Elmore County  Alabama          71437         155300
# 26                    Escambia County  Alabama          48727          94500
# 27                      Etowah County  Alabama          55354         105100
# 28                     Fayette County  Alabama          50889          83200
# 29                    Franklin County  Alabama          50902          87600
# ..                                ...      ...            ...            ...
# 70                 Bethel Census Area   Alaska          67827         152600
# 71                Bristol Bay Borough   Alaska          93172         186700
# 72                     Denali Borough   Alaska          90822         224200
# 73             Dillingham Census Area   Alaska          72392         189500
# 74       Fairbanks North Star Borough   Alaska          91968         230600
# 75                     Haines Borough   Alaska          84311         243100
# 76          Hoonah-Angoon Census Area   Alaska          72020         226800
# 77            Juneau City and Borough   Alaska         106849         343100
# 78            Kenai Peninsula Borough   Alaska          82690         234600
# 79          Ketchikan Gateway Borough   Alaska          83221         265700
# 80              Kodiak Island Borough   Alaska          88572         267700
# 81               Kusilvak Census Area   Alaska          47396          88600
# 82         Lake and Peninsula Borough   Alaska          62034         118500
# 83          Matanuska-Susitna Borough   Alaska          88473         235600
# 84                   Nome Census Area   Alaska          69905         143000
# 85                North Slope Borough   Alaska          94748         153900
# 86           Northwest Arctic Borough   Alaska          79496         145800
# 87                 Petersburg Borough   Alaska          83850         205000
# 88  Prince of Wales-Hyder Census Area   Alaska          65973         169100
# 89             Sitka City and Borough   Alaska          84007         350900
# 90               Skagway Municipality   Alaska          81260         293800
# 91    Southeast Fairbanks Census Area   Alaska          74772         191700
# 92         Valdez-Cordova Census Area   Alaska          99003         252200
# 93          Wrangell City and Borough   Alaska          67544         194000
# 94           Yakutat City and Borough   Alaska          70348         185000
# 95          Yukon-Koyukuk Census Area   Alaska          51731          80600
# 96                      Apache County  Arizona          43510          72800
# 97                     Cochise County  Arizona          61398         144400
# 98                    Coconino County  Arizona          72255         241400
# 99                        Gila County  Arizona          54167         153600
#
#     Zillow Home Value  Zillow Bottom Tier Home Value  \
# 0            159300.0                            NaN
# 1            213600.0                       134800.0
# 2                 NaN                            NaN
# 3                 NaN                            NaN
# 4            140600.0                        82700.0
# 5                 NaN                            NaN
# 6                 NaN                            NaN
# 7                 NaN                            NaN
# 8                 NaN                            NaN
# 9            117300.0                        55100.0
# 10           118400.0                        54900.0
# 11                NaN                            NaN
# 12                NaN                            NaN
# 13                NaN                            NaN
# 14                NaN                            NaN
# 15           114400.0                            NaN
# 16            96500.0                        50600.0
# 17                NaN                            NaN
# 18                NaN                            NaN
# 19                NaN                            NaN
# 20                NaN                            NaN
# 21                NaN                            NaN
# 22                NaN                            NaN
# 23                NaN                            NaN
# 24                NaN                            NaN
# 25           163300.0                        88500.0
# 26                NaN                            NaN
# 27           103100.0                            NaN
# 28                NaN                            NaN
# 29                NaN                            NaN
# ..                ...                            ...
# 70                NaN                            NaN
# 71                NaN                            NaN
# 72                NaN                            NaN
# 73                NaN                            NaN
# 74           253800.0                       166000.0
# 75                NaN                            NaN
# 76                NaN                            NaN
# 77                NaN                            NaN
# 78           245900.0                       175100.0
# 79           286800.0                       185800.0
# 80           334100.0                       234200.0
# 81                NaN                            NaN
# 82                NaN                            NaN
# 83                NaN                            NaN
# 84                NaN                            NaN
# 85                NaN                            NaN
# 86                NaN                            NaN
# 87                NaN                            NaN
# 88                NaN                            NaN
# 89                NaN                            NaN
# 90                NaN                            NaN
# 91                NaN                            NaN
# 92                NaN                            NaN
# 93                NaN                            NaN
# 94                NaN                            NaN
# 95                NaN                            NaN
# 96           159500.0                        92000.0
# 97           143400.0                        74200.0
# 98           353200.0                       231300.0
# 99           206700.0                            NaN
#
#     Zillow Top Tier Home Value
# 0                     235400.0
# 1                     384900.0
# 2                          NaN
# 3                          NaN
# 4                     228600.0
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                     195100.0
# 10                    205100.0
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                    228800.0
# 16                    186200.0
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                    278600.0
# 26                         NaN
# 27                    175600.0
# 28                         NaN
# 29                         NaN
# ..                         ...
# 70                         NaN
# 71                         NaN
# 72                         NaN
# 73                         NaN
# 74                    347200.0
# 75                         NaN
# 76                         NaN
# 77                         NaN
# 78                    361600.0
# 79                    418700.0
# 80                    451000.0
# 81                         NaN
# 82                         NaN
# 83                         NaN
# 84                         NaN
# 85                         NaN
# 86                         NaN
# 87                         NaN
# 88                         NaN
# 89                         NaN
# 90                         NaN
# 91                         NaN
# 92                         NaN
# 93                         NaN
# 94                         NaN
# 95                         NaN
# 96                    263600.0
# 97                    237800.0
# 98                    545700.0
# 99                    345000.0
#
# [100 rows x 8 columns]

# %%
data_table.to_csv("./Input Files/Income and Housing Data.csv", index=False, header=True)
