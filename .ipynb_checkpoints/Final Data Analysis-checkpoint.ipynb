# %% [markdown]
# # Final Data Analysis

# %% [markdown]
# ## Question 1 - Is there a correlation between weather and housing prices?
#
# - There seems to be a correlation between rain fall and housing prices, there are hardly counties that have an average home price above 200,000 that have over an average daily rain fall of over .2".
# - There also seems to be the same kind of relationship between average wind speed and home value. Very few counties with and median home price over 200,000 had an average wind speed over 15 mph.
# - There is much less of a correlation between temperature and house value, there does seem to be a slight upper limit of around 50 degrees for the average temperature.
# - There was no observable correlation between humidity and house value.

# %%
from IPython.display import Image
Image("Figures/Med Home Value vs Avg Percip.png")

# %%
Image("Figures/Med Home Value vs Avg Wind.png")

# %%
Image("Figures/Med Home Value vs Avg Temp.png")

# %%
Image("Figures/Med Home Value vs Max Humidity.png")

# %% [markdown]
# ## Question 2 - Is there a correlation between location and housing prices?
#
#  - When the data is plotted against latitude and longitude vs home value the more expensive counties fell between a latitude of less than 50 greater than 30 and a longitude greater than -80 and less than -100
#  - The correlations for houing prices seems to be stronger based on location and specifically longitude

# %%
Image("Figures/Best Weather - Med Home Value vs Latitude.png")

# %%
Image("Figures/Best Weather - Med Home Value vs Longitude.png")

# %% [markdown]
# ## Question 3 - What are the least expensive places to live with the nicest weather?
#
# - When the data is filtered according to the criteria determined from the previous two questions and then refined by filtering out the highest median home value counties it it apparent that he some of the most afforadable nice places to live are in Virginia and North Carolina

# %%
Image("Figures/Heat Map of Cheapest Counties with the Best Weather and Location.png")
